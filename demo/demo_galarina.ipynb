# %%
from galarina import gala, galarina

import stackview

# %%
# %gala an image of a cat
# Out:
# StackViewNDArray([[[ 97,  61,  42],
#                    [ 98,  60,  41],
#                    [ 97,  61,  42],
#                    ...,
#                    [ 11,  10,   7],
#                    [ 10,  10,   8],
#                    [ 11,  11,   8]],
#
#                   [[100,  62,  43],
#                    [100,  63,  44],
#                    [101,  63,  44],
#                    ...,
#                    [ 11,  11,   8],
#                    [ 11,  11,   8],
#                    [ 12,  11,  10]],
#
#                   [[102,  64,  45],
#                    [102,  65,  45],
#                    [102,  64,  45],
#                    ...,
#                    [ 10,  11,   8],
#                    [ 11,  11,   8],
#                    [ 11,  10,   9]],
#
#                   ...,
#
#                   [[141, 132, 103],
#                    [134, 123,  94],
#                    [137, 126,  94],
#                    ...,
#                    [233, 222, 139],
# ...

# %%
# %%gala 3
# image of cat

# %%
images = galarina(prompt="image of cat", num_images=2, image_size=512)
images.shape
# Out:
# (2, 512, 512, 3)

# %%
stackview.insight(images[0])
# Out:
# StackViewNDArray([[[ 12,  10,  11],
#                    [ 13,  11,  11],
#                    [ 17,  14,  15],
#                    ...,
#                    [ 91,  97,  13],
#                    [106, 104,  10],
#                    [ 75,  73,   0]],
#
#                   [[ 24,  19,  18],
#                    [ 19,  13,  12],
#                    [ 33,  26,  23],
#                    ...,
#                    [114, 118,  18],
#                    [145, 144,  17],
#                    [116, 118,  10]],
#
#                   [[ 39,  30,  26],
#                    [ 46,  32,  29],
#                    [ 63,  44,  40],
#                    ...,
#                    [125, 128,  17],
#                    [178, 179,  28],
#                    [186, 190,  44]],
#
#                   ...,
#
#                   [[213, 105,  31],
#                    [206, 104,  36],
#                    [165,  75,  22],
#                    ...,
#                    [235, 201, 197],
# ...
