# %%
from darth_d import create

import stackview

# %%
image = create("an image of a cat")

image
# Out:
# StackViewNDArray([[[131, 130, 121],
#                    [ 82,  82,  73],
#                    [ 39,  39,  34],
#                    ...,
#                    [ 60,  48,  58],
#                    [ 57,  43,  55],
#                    [ 59,  46,  59]],
#
#                   [[131, 129, 119],
#                    [ 71,  70,  61],
#                    [ 31,  32,  26],
#                    ...,
#                    [ 56,  49,  62],
#                    [ 58,  46,  58],
#                    [ 58,  45,  57]],
#
#                   [[119, 117, 105],
#                    [ 53,  53,  44],
#                    [ 24,  25,  20],
#                    ...,
#                    [ 75,  73,  90],
#                    [ 62,  55,  68],
#                    [ 52,  40,  50]],
#
#                   ...,
#
#                   [[253,  99, 157],
#                    [254, 100, 157],
#                    [253,  98, 156],
#                    ...,
#                    [178,  61,  83],
#                    [178,  61,  84],
#                    [178,  61,  84]],
#
#                   [[253,  99, 157],
#                    [254, 100, 157],
#                    [253,  99, 157],
#                    ...,
#                    [180,  61,  83],
#                    [180,  62,  83],
#                    [179,  63,  85]],
#
#                   [[253, 100, 157],
#                    [253, 100, 157],
#                    [253, 100, 157],
#                    ...,
#                    [183,  62,  83],
#                    [182,  63,  84],
#                    [182,  64,  86]]], dtype=uint8)

# %%
images = create("an image of a bird", num_images=3)

stackview.slice(images)
# Out:
# VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=256, width=256),)),)), IntSlider(value=1, desc…
