# %%
from darth_d import create

import stackview

# %%
image = create("an image of a cat")

image
# Out:
# StackViewNDArray([[[ 63, 132, 131],
#                    [ 58, 128, 127],
#                    [ 59, 127, 127],
#                    ...,
#                    [  2,   3,   3],
#                    [  3,   3,   3],
#                    [  2,   3,   2]],
#
#                   [[ 63, 132, 130],
#                    [ 66, 135, 135],
#                    [ 64, 134, 133],
#                    ...,
#                    [  2,   3,   2],
#                    [  3,   3,   3],
#                    [  3,   3,   2]],
#
#                   [[ 64, 133, 131],
#                    [ 62, 131, 129],
#                    [ 64, 133, 132],
#                    ...,
#                    [  3,   3,   2],
#                    [  3,   3,   2],
#                    [  3,   3,   2]],
#
#                   ...,
#
#                   [[ 11,  14,  10],
#                    [ 11,  13,  10],
#                    [ 11,  12,  10],
#                    ...,
#                    [ 14,  16,  17],
#                    [ 14,  15,  16],
#                    [ 13,  16,  16]],
#
#                   [[ 12,  14,  10],
#                    [ 11,  13,  10],
#                    [ 11,  12,  10],
#                    ...,
#                    [ 14,  16,  17],
#                    [ 16,  18,  19],
#                    [ 17,  19,  20]],
#
#                   [[ 13,  14,  12],
#                    [ 13,  15,  11],
#                    [ 12,  14,  11],
#                    ...,
#                    [ 13,  15,  16],
#                    [ 14,  16,  17],
#                    [ 15,  17,  18]]], dtype=uint8)

# %%
images = create("an image of a bird", num_images=3)

stackview.slice(images)
# Out:
# VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=256, width=256),)),)), IntSlider(value=1, desc…
