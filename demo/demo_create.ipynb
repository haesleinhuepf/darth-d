# %%
from darth_d import create

import stackview

# %%
image = create("an image of a cat")

image
# Out:
# StackViewNDArray([[[255, 244, 157],
#                    [250, 242, 166],
#                    [249, 243, 168],
#                    ...,
#                    [ 58,  58,  50],
#                    [ 60,  59,  53],
#                    [ 59,  58,  52]],
#
#                   [[250, 242, 153],
#                    [248, 243, 156],
#                    [248, 245, 156],
#                    ...,
#                    [ 58,  60,  53],
#                    [ 56,  58,  51],
#                    [ 58,  57,  50]],
#
#                   [[248, 240, 153],
#                    [248, 243, 156],
#                    [249, 245, 153],
#                    ...,
#                    [ 60,  59,  55],
#                    [ 58,  57,  54],
#                    [ 58,  59,  52]],
#
#                   ...,
#
#                   [[247, 239, 209],
#                    [234, 227, 205],
#                    [191, 171, 132],
#                    ...,
#                    [ 62,  50,  48],
# ...

# %%
image = create("an image of a cat", model='dall-e-2', image_width=256, image_height=256)

image
# Out:
# StackViewNDArray([[[ 18,  18,  16],
#                    [ 17,  18,  15],
#                    [ 18,  19,  17],
#                    ...,
#                    [143, 140,  60],
#                    [146, 144,  65],
#                    [147, 146,  70]],
#
#                   [[ 17,  18,  16],
#                    [ 19,  19,  16],
#                    [ 18,  19,  15],
#                    ...,
#                    [141, 139,  58],
#                    [144, 142,  66],
#                    [147, 145,  71]],
#
#                   [[ 17,  17,  15],
#                    [ 16,  17,  14],
#                    [ 16,  17,  15],
#                    ...,
#                    [141, 138,  57],
#                    [147, 144,  69],
#                    [149, 147,  74]],
#
#                   ...,
#
#                   [[  7,   7,   5],
#                    [  7,   7,   5],
#                    [  7,   7,   5],
#                    ...,
#                    [  6,   8,   6],
# ...

# %%
images = create("an image of a bird", num_images=3, model='dall-e-2', image_height=256, image_width=256)

stackview.slice(images)
