# %%
from darth_d import create

import stackview

# %%
image = create("an image of a cat")

image
# Out:
# StackViewNDArray([[[203,  96,  98],
#                    [204,  96,  97],
#                    [205,  96,  98],
#                    ...,
#                    [218, 107, 115],
#                    [217, 108, 115],
#                    [217, 107, 115]],
#
#                   [[209,  97, 101],
#                    [209,  99, 101],
#                    [210, 100, 102],
#                    ...,
#                    [217, 108, 115],
#                    [217, 108, 115],
#                    [217, 107, 115]],
#
#                   [[213, 100, 104],
#                    [214, 101, 104],
#                    [214, 102, 106],
#                    ...,
#                    [218, 109, 115],
#                    [218, 108, 116],
#                    [217, 108, 114]],
#
#                   ...,
#
#                   [[ 40,  42,  37],
#                    [ 56,  57,  51],
#                    [ 70,  71,  65],
#                    ...,
#                    [233, 194, 149],
# ...

# %%
images = create("an image of a cat", num_images=3)

stackview.slice(images)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 images = create("an image of a cat", num_images=3)
#       3 stackview.slice(images)
#
# File c:\structure\code\stackview\stackview\_static_view.py:25, in jupyter_displayable_output.<locals>.worker_function(*args, **kwargs)
#      22 @wraps(function)
#      23 def worker_function(*args, **kwargs):
#      24     # call the decorated function
# ---> 25     result = function(*args, **kwargs)
#      27     # Attach _repr_html_ function
#      28     result = StackViewNDArray(result, library_name, help_url)
#
# File c:\structure\code\darth-d\darth_d\_create.py:10, in create(prompt, image_size, num_images)
#       6 import openai
#       8 from ._utilities import images_from_url_responses
# ---> 10 response = openai.Image.create(
#      11   prompt=prompt,
#      12   n=num_images,
# ...
