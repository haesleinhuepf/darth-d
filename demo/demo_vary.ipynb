# %%
from darth_d import vary

from skimage.io import imread
import stackview

# %%
image = imread("real_cat.png")

# %%
stackview.insight(image)
# Out:
# StackViewNDArray([[[176, 178, 179],
#                    [175, 178, 178],
#                    [177, 177, 180],
#                    ...,
#                    [182, 186, 188],
#                    [185, 188, 191],
#                    [191, 194, 197]],
#
#                   [[178, 180, 181],
#                    [178, 179, 181],
#                    [178, 180, 181],
#                    ...,
#                    [185, 189, 192],
#                    [187, 191, 192],
#                    [191, 195, 198]],
#
#                   [[181, 183, 185],
#                    [180, 182, 183],
#                    [180, 181, 183],
#                    ...,
#                    [190, 193, 196],
#                    [189, 193, 196],
#                    [192, 195, 198]],
#
#                   ...,
#
#                   [[125,  91,  66],
#                    [124,  90,  65],
#                    [123,  89,  65],
#                    ...,
#                    [137,  92,  64],
#                    [136,  91,  62],
#                    [135,  89,  61]],
#
#                   [[122,  88,  64],
#                    [121,  87,  63],
#                    [121,  87,  63],
#                    ...,
#                    [142,  96,  68],
#                    [142,  96,  68],
#                    [139,  94,  65]],
#
#                   [[120,  86,  62],
#                    [120,  86,  60],
#                    [119,  85,  61],
#                    ...,
#                    [144,  99,  70],
#                    [144,  99,  70],
#                    [142,  97,  68]]], dtype=uint8)

# %%
output_image = vary(image)

output_image
# Out:
# c:\structure\code\darth-d\darth_d\_vary.py:28: UserWarning: Using the replace function on scientific images could be seen as scientific misconduct. Handle this function with care.
#   warn("Using the replace function on scientific images could be seen as scientific misconduct. Handle this function with care.")
# StackViewNDArray([[[155, 151, 144],
#                    [155, 151, 144],
#                    [155, 151, 144],
#                    ...,
#                    [154, 147, 138],
#                    [154, 147, 138],
#                    [154, 147, 138]],
#
#                   [[155, 151, 144],
#                    [155, 151, 144],
#                    [155, 151, 144],
#                    ...,
#                    [154, 147, 138],
#                    [154, 147, 138],
#                    [154, 147, 138]],
#
#                   [[155, 151, 144],
#                    [155, 151, 144],
#                    [155, 151, 144],
#                    ...,
#                    [154, 147, 138],
#                    [154, 147, 138],
#                    [154, 147, 138]],
#
#                   ...,
#
#                   [[162, 116,  76],
#                    [162, 116,  76],
#                    [162, 116,  76],
#                    ...,
#                    [190, 133,  88],
#                    [190, 133,  87],
#                    [190, 133,  87]],
#
#                   [[164, 117,  78],
#                    [164, 117,  78],
#                    [164, 118,  78],
#                    ...,
#                    [190, 133,  87],
#                    [190, 133,  87],
#                    [190, 133,  87]],
#
#                   [[164, 117,  78],
#                    [164, 117,  78],
#                    [164, 118,  78],
#                    ...,
#                    [190, 133,  87],
#                    [190, 133,  87],
#                    [190, 133,  87]]], dtype=uint8)
