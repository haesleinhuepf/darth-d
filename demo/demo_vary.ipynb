# %%
from darth_d import vary

from skimage.io import imread
import stackview

# %%
image = imread("real_cat.png")

# %%
stackview.insight(image)
# Out:
# StackViewNDArray([[[176, 178, 179],
#                    [175, 178, 178],
#                    [177, 177, 180],
#                    ...,
#                    [182, 186, 188],
#                    [185, 188, 191],
#                    [191, 194, 197]],
#
#                   [[178, 180, 181],
#                    [178, 179, 181],
#                    [178, 180, 181],
#                    ...,
#                    [185, 189, 192],
#                    [187, 191, 192],
#                    [191, 195, 198]],
#
#                   [[181, 183, 185],
#                    [180, 182, 183],
#                    [180, 181, 183],
#                    ...,
#                    [190, 193, 196],
#                    [189, 193, 196],
#                    [192, 195, 198]],
#
#                   ...,
#
#                   [[125,  91,  66],
#                    [124,  90,  65],
#                    [123,  89,  65],
#                    ...,
#                    [137,  92,  64],
#                    [136,  91,  62],
#                    [135,  89,  61]],
#
#                   [[122,  88,  64],
#                    [121,  87,  63],
#                    [121,  87,  63],
#                    ...,
#                    [142,  96,  68],
#                    [142,  96,  68],
#                    [139,  94,  65]],
#
#                   [[120,  86,  62],
#                    [120,  86,  60],
#                    [119,  85,  61],
#                    ...,
#                    [144,  99,  70],
#                    [144,  99,  70],
#                    [142,  97,  68]]], dtype=uint8)

# %%
output_image = vary(image)

output_image
# Out:
# c:\structure\code\darth-d\darth_d\_vary.py:36: UserWarning: Using the vary function on scientific images could be seen as scientific misconduct. Handle this function with care.
#   warn("Using the vary function on scientific images could be seen as scientific misconduct. Handle this function with care.")
# StackViewNDArray([[[208, 213, 214],
#                    [210, 215, 217],
#                    [210, 215, 216],
#                    ...,
#                    [251, 252, 251],
#                    [252, 252, 251],
#                    [251, 253, 251]],
#
#                   [[208, 214, 214],
#                    [209, 215, 216],
#                    [208, 216, 216],
#                    ...,
#                    [252, 253, 251],
#                    [252, 253, 251],
#                    [252, 253, 252]],
#
#                   [[209, 214, 214],
#                    [209, 213, 214],
#                    [209, 215, 216],
#                    ...,
#                    [252, 252, 252],
#                    [253, 253, 253],
#                    [251, 252, 251]],
#
#                   ...,
#
#                   [[175, 129,  84],
#                    [173, 128,  81],
#                    [175, 128,  82],
#                    ...,
#                    [228, 213, 184],
#                    [230, 212, 184],
#                    [231, 214, 187]],
#
#                   [[177, 129,  84],
#                    [175, 128,  83],
#                    [174, 128,  82],
#                    ...,
#                    [230, 215, 186],
#                    [230, 213, 186],
#                    [230, 215, 187]],
#
#                   [[176, 131,  84],
#                    [177, 130,  86],
#                    [174, 129,  82],
#                    ...,
#                    [230, 215, 186],
#                    [229, 215, 187],
#                    [229, 216, 188]]], dtype=uint8)
