# %%
from skimage.io import imread
from galarina import vary, gala
import stackview

# %%
image = imread("real_cat.png")

# %%
stackview.insight(image)
# Out:
# StackViewNDArray([[[176, 178, 179],
#                    [175, 178, 178],
#                    [177, 177, 180],
#                    ...,
#                    [182, 186, 188],
#                    [185, 188, 191],
#                    [191, 194, 197]],
#
#                   [[178, 180, 181],
#                    [178, 179, 181],
#                    [178, 180, 181],
#                    ...,
#                    [185, 189, 192],
#                    [187, 191, 192],
#                    [191, 195, 198]],
#
#                   [[181, 183, 185],
#                    [180, 182, 183],
#                    [180, 181, 183],
#                    ...,
#                    [190, 193, 196],
#                    [189, 193, 196],
#                    [192, 195, 198]],
#
#                   ...,
#
#                   [[125,  91,  66],
#                    [124,  90,  65],
#                    [123,  89,  65],
#                    ...,
#                    [137,  92,  64],
# ...

# %%
output_image = vary(image)

stackview.insight(output_image)
# Out:
# StackViewNDArray([[[255, 255, 254],
#                    [255, 255, 254],
#                    [254, 255, 253],
#                    ...,
#                    [182, 180, 175],
#                    [181, 179, 175],
#                    [181, 179, 175]],
#
#                   [[255, 255, 254],
#                    [255, 255, 254],
#                    [255, 255, 253],
#                    ...,
#                    [181, 179, 174],
#                    [181, 179, 174],
#                    [181, 179, 174]],
#
#                   [[255, 255, 254],
#                    [255, 255, 254],
#                    [255, 255, 253],
#                    ...,
#                    [181, 178, 174],
#                    [181, 178, 173],
#                    [181, 178, 173]],
#
#                   ...,
#
#                   [[254, 255, 254],
#                    [255, 255, 255],
#                    [255, 255, 255],
#                    ...,
#                    [149, 110,  84],
# ...

# %%
# %%gala vary
# image
